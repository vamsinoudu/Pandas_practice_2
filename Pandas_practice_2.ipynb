# %%
import pandas as pd
import numpy as np

data = pd.read_csv("C:\\Users\\vamsi\\Downloads\\train_data_1.csv")
data
# Out:
#         member_id  loan_amnt  funded_amnt  funded_amnt_inv       term  \
# 0        58189336      14350        14350      14350.00000  36 months
# 1        70011223       4800         4800       4800.00000  36 months
# 2        70255675      10000        10000      10000.00000  36 months
# 3         1893936      15000        15000      15000.00000  36 months
# 4         7652106      16000        16000      16000.00000  36 months
# ...           ...        ...          ...              ...        ...
# 269995   35623179       4200         4200       4200.00000  36 months
# 269996   10326761      20000        20000      20000.00000  36 months
# 269997     656855      12000        12000      11127.82258  36 months
# 269998   14679847      22000        22000      22000.00000  36 months
# 269999   66255702      15625        15625      15625.00000  60 months
#
#        batch_enrolled  int_rate grade sub_grade  \
# 0                 NaN     19.19     E        E3
# ...

# %%
# How to create a col:
#df =pd.read_csv("C:\\Users\\vamsi\\Downloads\\train_data_1.csv")
df['Average score']=round( (df['loan_amnt']/36))
df
# Out:
#         member_id  loan_amnt  funded_amnt  funded_amnt_inv       term  \
# 0        58189336      14350        14350      14350.00000  36 months
# 1        70011223       4800         4800       4800.00000  36 months
# 2        70255675      10000        10000      10000.00000  36 months
# 3         1893936      15000        15000      15000.00000  36 months
# 4         7652106      16000        16000      16000.00000  36 months
# ...           ...        ...          ...              ...        ...
# 269995   35623179       4200         4200       4200.00000  36 months
# 269996   10326761      20000        20000      20000.00000  36 months
# 269997     656855      12000        12000      11127.82258  36 months
# 269998   14679847      22000        22000      22000.00000  36 months
# 269999   66255702      15625        15625      15625.00000  60 months
#
#        batch_enrolled  int_rate grade sub_grade  \
# 0                 NaN     19.19     E        E3
# ...

# %%
# Drop a col:

df.drop("loan_amnt",axis=1,inplace=True)
df
# Out:
#         funded_amnt  funded_amnt_inv       term batch_enrolled  int_rate  \
# 0             14350      14350.00000  36 months            NaN     19.19
# 1              4800       4800.00000  36 months     BAT1586599     10.99
# 2             10000      10000.00000  36 months     BAT1586599      7.26
# 3             15000      15000.00000  36 months     BAT4808022     19.72
# 4             16000      16000.00000  36 months     BAT2833642     10.64
# ...             ...              ...        ...            ...       ...
# 269995         4200       4200.00000  36 months            NaN     13.98
# 269996        20000      20000.00000  36 months     BAT2575549     13.67
# 269997        12000      11127.82258  36 months            NaN      7.88
# 269998        22000      22000.00000  36 months            NaN     12.49
# 269999        15625      15625.00000  60 months     BAT2252229     25.78
#
#        grade sub_grade                           emp_title emp_length  \
# ...

# %%
# dropping two col:(multiple columns)

df.drop(["funded_amnt_inv","funded_amnt"],axis=1,inplace =True)
df
# Out:
#        batch_enrolled  int_rate grade sub_grade  \
# 0                 NaN     19.19     E        E3
# 1          BAT1586599     10.99     B        B4
# 2          BAT1586599      7.26     A        A4
# 3          BAT4808022     19.72     D        D5
# 4          BAT2833642     10.64     B        B2
# ...               ...       ...   ...       ...
# 269995            NaN     13.98     C        C3
# 269996     BAT2575549     13.67     B        B5
# 269997            NaN      7.88     A        A5
# 269998            NaN     12.49     B        B4
# 269999     BAT2252229     25.78     F        F5
#
#                                  emp_title emp_length home_ownership  \
# 0                                    clerk    9 years            OWN
# 1               Human Resources Specialist   < 1 year       MORTGAGE
# 2                                   Driver    2 years            OWN
# 3        Us office of Personnel Management  10+ years           RENT
# ...

# %%
# drop rows:{single}
df.drop([10],axis=0,inplace = True)
df
# Out:
#        batch_enrolled  int_rate grade sub_grade  \
# 0                 NaN     19.19     E        E3
# 1          BAT1586599     10.99     B        B4
# 2          BAT1586599      7.26     A        A4
# 6                 NaN      7.90     A        A4
# 7                 NaN      9.17     B        B1
# ...               ...       ...   ...       ...
# 269995            NaN     13.98     C        C3
# 269996     BAT2575549     13.67     B        B5
# 269997            NaN      7.88     A        A5
# 269998            NaN     12.49     B        B4
# 269999     BAT2252229     25.78     F        F5
#
#                                  emp_title emp_length home_ownership  \
# 0                                    clerk    9 years            OWN
# 1               Human Resources Specialist   < 1 year       MORTGAGE
# 2                                   Driver    2 years            OWN
# 6                TOYOTA OF NORTH HOLLYWOOD    5 years           RENT
# ...

# %%
df.shape
# Out:
# (269996, 41)

# %%
###### slicing in df:
#dfName.loc[rowName,colName]

#dfName.loc[rowIndex,colIndex]
df.head()
# Out:
#   batch_enrolled  int_rate grade sub_grade                   emp_title  \
# 0            NaN     19.19     E        E3                       clerk
# 1     BAT1586599     10.99     B        B4  Human Resources Specialist
# 2     BAT1586599      7.26     A        A4                      Driver
# 6            NaN      7.90     A        A4   TOYOTA OF NORTH HOLLYWOOD
# 7            NaN      9.17     B        B1                      Banker
#
#   emp_length home_ownership  annual_inc verification_status pymnt_plan  ...  \
# 0    9 years            OWN     28700.0     Source Verified          n  ...
# 1   < 1 year       MORTGAGE     65000.0     Source Verified          n  ...
# 2    2 years            OWN     45000.0        Not Verified          n  ...
# 6    5 years           RENT     75000.0     Source Verified          n  ...
# 7    8 years       MORTGAGE     54000.0        Not Verified          n  ...
#
#   mths_since_last_major_derog application_type verification_status_joint  \
# ...

# %%
df.loc[(2,6,7),["grade","sub_grade"]]
# Out:
#   grade sub_grade
# 2     A        A4
# 6     A        A4
# 7     B        B1

# %%
df.loc[:,["grade","sub_grade"]]  #start : 0 ; end : len og seq
# Out:
#        grade sub_grade
# 0          E        E3
# 1          B        B4
# 2          A        A4
# 6          A        A4
# 7          B        B1
# ...      ...       ...
# 269995     C        C3
# 269996     B        B5
# 269997     A        A5
# 269998     B        B4
# 269999     F        F5
#
# [269996 rows x 2 columns]

# %%
df.loc[(2,6,7),:]    # end : len of seq:
# Out:
#   batch_enrolled  int_rate grade sub_grade                  emp_title  \
# 2     BAT1586599      7.26     A        A4                     Driver
# 6            NaN      7.90     A        A4  TOYOTA OF NORTH HOLLYWOOD
# 7            NaN      9.17     B        B1                     Banker
#
#   emp_length home_ownership  annual_inc verification_status pymnt_plan  ...  \
# 2    2 years            OWN     45000.0        Not Verified          n  ...
# 6    5 years           RENT     75000.0     Source Verified          n  ...
# 7    8 years       MORTGAGE     54000.0        Not Verified          n  ...
#
#   mths_since_last_major_derog application_type verification_status_joint  \
# 2                         NaN       INDIVIDUAL                       NaN
# 6                         NaN       INDIVIDUAL                       NaN
# 7                        54.0       INDIVIDUAL                       NaN
#
#   last_week_pay acc_now_delinq  tot_coll_amt  tot_cur_bal  total_rev_hi_lim  \
# ...

# %%
df.loc[:,"zip_code"]
# Out:
# 0         349xx
# 1         209xx
# 2         447xx
# 6         913xx
# 7         351xx
#           ...
# 269995    144xx
# 269996    073xx
# 269997    191xx
# 269998    721xx
# 269999    891xx
# Name: zip_code, Length: 269996, dtype: object

# %%
df.head()
# Out:
#   batch_enrolled  int_rate grade sub_grade                   emp_title  \
# 0            NaN     19.19     E        E3                       clerk
# 1     BAT1586599     10.99     B        B4  Human Resources Specialist
# 2     BAT1586599      7.26     A        A4                      Driver
# 6            NaN      7.90     A        A4   TOYOTA OF NORTH HOLLYWOOD
# 7            NaN      9.17     B        B1                      Banker
#
#   emp_length home_ownership  annual_inc verification_status pymnt_plan  ...  \
# 0    9 years            OWN     28700.0     Source Verified          n  ...
# 1   < 1 year       MORTGAGE     65000.0     Source Verified          n  ...
# 2    2 years            OWN     45000.0        Not Verified          n  ...
# 6    5 years           RENT     75000.0     Source Verified          n  ...
# 7    8 years       MORTGAGE     54000.0        Not Verified          n  ...
#
#   mths_since_last_major_derog application_type verification_status_joint  \
# ...

# %%
# df iloc[rowIndex,colIndex]

#select of first 3 rows

#0 1 2

df.iloc[0:3 , :]
# Out:
#   batch_enrolled  int_rate grade sub_grade                   emp_title  \
# 0            NaN     19.19     E        E3                       clerk
# 1     BAT1586599     10.99     B        B4  Human Resources Specialist
# 2     BAT1586599      7.26     A        A4                      Driver
#
#   emp_length home_ownership  annual_inc verification_status pymnt_plan  ...  \
# 0    9 years            OWN     28700.0     Source Verified          n  ...
# 1   < 1 year       MORTGAGE     65000.0     Source Verified          n  ...
# 2    2 years            OWN     45000.0        Not Verified          n  ...
#
#   mths_since_last_major_derog application_type verification_status_joint  \
# 0                        74.0       INDIVIDUAL                       NaN
# 1                         NaN       INDIVIDUAL                       NaN
# 2                         NaN       INDIVIDUAL                       NaN
#
#   last_week_pay acc_now_delinq  tot_coll_amt  tot_cur_bal  total_rev_hi_lim  \
# ...

# %%
# select last 2 col :

# head

df.iloc[:,-2: ].head()
# Out:
#    loan_status  Average score
# 0            0          399.0
# 1            0          133.0
# 2            0          278.0
# 6            1          139.0
# 7            0          167.0

# %%
# tail:
df.iloc[:,-3:].tail()
# Out:
#         total_rev_hi_lim  loan_status  Average score
# 269995            7200.0            0          117.0
# 269996           59200.0            0          556.0
# 269997               NaN            1          333.0
# 269998           34500.0            0          611.0
# 269999           49800.0            0          434.0

# %%
df.iloc[5:10,2:5]
# Out:
#    grade sub_grade                emp_title
# 8      C        C4                      LVN
# 9      D        D4         Registered Nurse
# 11     D        D2     Jp Morgan chase bank
# 12     A        A3                   driver
# 13     A        A1  Federal Law Enforcement
